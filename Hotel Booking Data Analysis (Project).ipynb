# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('Hotel Booking 1')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0  Resort Hotel            0        342                        0
# 1  Resort Hotel            0        737                        0
# 2  Resort Hotel            0          7                        0
# 3  Resort Hotel            0         13                        0
# 4  Resort Hotel            0         14                        0
#
#    stays_in_weekend_nights.1  stays_in_weekend_nights.2  \
# 0                          1                          2
# 1                          1                          2
# 2                          1                          2
# 3                          1                          2
# 4                          1                          2
#
#    stays_in_weekend_nights.3  babies meal country  ... deposit_type  agent  \
# 0                          3       0   BB     PRT  ...   No Deposit    NaN
# 1                          3       0   BB     PRT  ...   No Deposit    NaN
# 2                          3       0   BB     GBR  ...   No Deposit    NaN
# 3                          3       0   BB     GBR  ...   No Deposit  304.0
# 4                          3       0   BB     GBR  ...   No Deposit  240.0
#
#    company  days_in_waiting_list  customer_type   adr  \
# 0      NaN                     0      Transient   0.0
# 1      NaN                     0      Transient   0.0
# 2      NaN                     0      Transient  75.0
# 3      NaN                     0      Transient  75.0
# 4      NaN                     0      Transient  98.0
#
#   required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                           0                          0          Check-Out
# 1                           0                          0          Check-Out
# 2                           0                          0          Check-Out
# 3                           0                          0          Check-Out
# 4                           0                          1          Check-Out
#
#    reservation_status_date
# 0               01-07-2015
# 1               01-07-2015
# 2               02-07-2015
# 3               02-07-2015
# 4               03-07-2015
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (119390, 28)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'stays_in_weekend_nights',
#        'stays_in_weekend_nights.1', 'stays_in_weekend_nights.2',
#        'stays_in_weekend_nights.3', 'babies', 'meal', 'country',
#        'market_segment', 'distribution_channel', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'reserved_room_type', 'assigned_room_type', 'booking_changes',
#        'deposit_type', 'agent', 'company', 'days_in_waiting_list',
#        'customer_type', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # Cleaning the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   stays_in_weekend_nights         119390 non-null  int64
#  4   stays_in_weekend_nights.1       119390 non-null  int64
#  5   stays_in_weekend_nights.2       119390 non-null  int64
#  6   stays_in_weekend_nights.3       119390 non-null  int64
#  7   babies                          119390 non-null  int64
#  8   meal                            119390 non-null  object
#  9   country                         118902 non-null  object
#  10  market_segment                  119390 non-null  object
#  11  distribution_channel            119390 non-null  object
#  12  is_repeated_guest               119390 non-null  int64
#  13  previous_cancellations          119390 non-null  int64
#  14  previous_bookings_not_canceled  119390 non-null  int64
#  15  reserved_room_type              119390 non-null  object
#  16  assigned_room_type              119390 non-null  object
#  17  booking_changes                 119390 non-null  int64
#  18  deposit_type                    119390 non-null  object
#  19  agent                           103050 non-null  float64
#  20  company                         6797 non-null    float64
#  21  days_in_waiting_list            119390 non-null  int64
#  22  customer_type                   119390 non-null  object
#  23  adr                             119390 non-null  float64
#  24  required_car_parking_spaces     119390 non-null  int64
#  25  total_of_special_requests       119390 non-null  int64
#  26  reservation_status              119390 non-null  object
#  27  reservation_status_date         119390 non-null  object
# dtypes: float64(3), int64(14), object(11)
# memory usage: 25.5+ MB

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   stays_in_weekend_nights         119390 non-null  int64
#  4   stays_in_weekend_nights.1       119390 non-null  int64
#  5   stays_in_weekend_nights.2       119390 non-null  int64
#  6   stays_in_weekend_nights.3       119390 non-null  int64
#  7   babies                          119390 non-null  int64
#  8   meal                            119390 non-null  object
#  9   country                         118902 non-null  object
#  10  market_segment                  119390 non-null  object
#  11  distribution_channel            119390 non-null  object
#  12  is_repeated_guest               119390 non-null  int64
#  13  previous_cancellations          119390 non-null  int64
#  14  previous_bookings_not_canceled  119390 non-null  int64
#  15  reserved_room_type              119390 non-null  object
#  16  assigned_room_type              119390 non-null  object
#  17  booking_changes                 119390 non-null  int64
#  18  deposit_type                    119390 non-null  object
#  19  agent                           103050 non-null  float64
#  20  company                         6797 non-null    float64
#  21  days_in_waiting_list            119390 non-null  int64
#  22  customer_type                   119390 non-null  object
#  23  adr                             119390 non-null  float64
#  24  required_car_parking_spaces     119390 non-null  int64
#  25  total_of_special_requests       119390 non-null  int64
#  26  reservation_status              119390 non-null  object
#  27  reservation_status_date         119390 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(14), object(10)
# memory usage: 25.5+ MB

# %%
df.describe()
# Out:
#          is_canceled      lead_time  stays_in_weekend_nights  \
# count  119390.000000  119390.000000            119390.000000
# mean        0.370416     104.011416                 0.927599
# std         0.482918     106.863097                 0.998613
# min         0.000000       0.000000                 0.000000
# 25%         0.000000      18.000000                 0.000000
# 50%         0.000000      69.000000                 1.000000
# 75%         1.000000     160.000000                 2.000000
# max         1.000000     737.000000                19.000000
#
#        stays_in_weekend_nights.1  stays_in_weekend_nights.2  \
# count              119390.000000              119390.000000
# mean                    1.927599                   2.927599
# std                     0.998613                   0.998613
# min                     1.000000                   2.000000
# 25%                     1.000000                   2.000000
# 50%                     2.000000                   3.000000
# 75%                     3.000000                   4.000000
# max                    20.000000                  21.000000
#
#        stays_in_weekend_nights.3         babies  is_repeated_guest  \
# count              119390.000000  119390.000000      119390.000000
# mean                    3.927599       0.007949           0.031912
# std                     0.998613       0.097436           0.175767
# min                     3.000000       0.000000           0.000000
# 25%                     3.000000       0.000000           0.000000
# 50%                     4.000000       0.000000           0.000000
# 75%                     5.000000       0.000000           0.000000
# max                    22.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           119390.000000                   119390.000000
# mean                 0.087118                        0.137097
# std                  0.844336                        1.497437
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes          agent      company  days_in_waiting_list  \
# count    119390.000000  103050.000000  6797.000000         119390.000000
# mean          0.221124      86.693382   189.266735              2.321149
# std           0.652306     110.774548   131.655015             17.594721
# min           0.000000       1.000000     6.000000              0.000000
# 25%           0.000000       9.000000    62.000000              0.000000
# 50%           0.000000      14.000000   179.000000              0.000000
# 75%           0.000000     229.000000   270.000000              0.000000
# max          21.000000     535.000000   543.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
df.describe(include = 'object')
# Out:
#              hotel    meal country market_segment distribution_channel  \
# count       119390  119390  118902         119390               119390
# unique           2       5     177              8                    5
# top     City Hotel      BB     PRT      Online TA                TA/TO
# freq         79330   92310   48590          56477                97870
#
#        reserved_room_type assigned_room_type deposit_type customer_type  \
# count              119390             119390       119390        119390
# unique                 10                 12            3             4
# top                     A                  A   No Deposit     Transient
# freq                85994              74053       104641         89613
#
#        reservation_status
# count              119390
# unique                  3
# top             Check-Out
# freq                75166

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
#  'KHM' 'MCO' 'BGD' 'IMN' 'TJK' 'NIC' 'BEN' 'VGB' 'TZA' 'GAB' 'GHA' 'TMP'
#  'GLP' 'KEN' 'LIE' 'GNB' 'MNE' 'UMI' 'MYT' 'FRO' 'MMR' 'PAN' 'BFA' 'LBY'
#  'MLI' 'NAM' 'BOL' 'PRY' 'BRB' 'ABW' 'AIA' 'SLV' 'DMA' 'PYF' 'GUY' 'LCA'
#  'ATA' 'GTM' 'ASM' 'MRT' 'NCL' 'KIR' 'SDN' 'ATF' 'SLE' 'LAO']
# --------------------------------------------------
# market_segment
# ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# --------------------------------------------------
# distribution_channel
# ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# --------------------------------------------------
# reserved_room_type
# ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# --------------------------------------------------
# assigned_room_type
# ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# --------------------------------------------------
# deposit_type
# ['No Deposit' 'Refundable' 'Non Refund']
# --------------------------------------------------
# customer_type
# ['Transient' 'Contract' 'Transient-Party' 'Group']
# --------------------------------------------------
# reservation_status
# ['Check-Out' 'Canceled' 'No-Show']
# --------------------------------------------------

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# stays_in_weekend_nights                0
# stays_in_weekend_nights.1              0
# stays_in_weekend_nights.2              0
# stays_in_weekend_nights.3              0
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
df.drop(['company','agent'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# stays_in_weekend_nights           0
# stays_in_weekend_nights.1         0
# stays_in_weekend_nights.2         0
# stays_in_weekend_nights.3         0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %%
df.describe()
# Out:
#          is_canceled      lead_time  stays_in_weekend_nights  \
# count  118902.000000  118902.000000            118902.000000
# mean        0.371373     104.308027                 0.928891
# std         0.483174     106.903127                 0.996211
# min         0.000000       0.000000                 0.000000
# 25%         0.000000      18.000000                 0.000000
# 50%         0.000000      69.000000                 1.000000
# 75%         1.000000     161.000000                 2.000000
# max         1.000000     737.000000                16.000000
#
#        stays_in_weekend_nights.1  stays_in_weekend_nights.2  \
# count              118902.000000              118902.000000
# mean                    1.928891                   2.928891
# std                     0.996211                   0.996211
# min                     1.000000                   2.000000
# 25%                     1.000000                   2.000000
# 50%                     2.000000                   3.000000
# 75%                     3.000000                   4.000000
# max                    17.000000                  18.000000
#
#        stays_in_weekend_nights.3         babies  is_repeated_guest  \
# count              118902.000000  118902.000000      118902.000000
# mean                    3.928891       0.007948           0.032010
# std                     0.996211       0.097379           0.176026
# min                     3.000000       0.000000           0.000000
# 25%                     3.000000       0.000000           0.000000
# 50%                     4.000000       0.000000           0.000000
# 75%                     5.000000       0.000000           0.000000
# max                    19.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           118902.000000                   118902.000000
# mean                 0.087139                        0.131629
# std                  0.845855                        1.484647
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes  days_in_waiting_list            adr  \
# count    118902.000000         118902.000000  118902.000000
# mean          0.221174              2.330676     102.000808
# std           0.652775             17.630161      50.487004
# min           0.000000              0.000000      -6.380000
# 25%           0.000000              0.000000      70.000000
# 50%           0.000000              0.000000      95.000000
# 75%           0.000000              0.000000     126.000000
# max          21.000000            391.000000    5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                118902.000000              118902.000000
# mean                      0.061883                   0.571706
# std                       0.244168                   0.792678
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %%
df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  stays_in_weekend_nights  \
# count  118901.000000  118901.000000            118901.000000
# mean        0.371368     104.308610                 0.928899
# std         0.483173     106.903388                 0.996212
# min         0.000000       0.000000                 0.000000
# 25%         0.000000      18.000000                 0.000000
# 50%         0.000000      69.000000                 1.000000
# 75%         1.000000     161.000000                 2.000000
# max         1.000000     737.000000                16.000000
#
#        stays_in_weekend_nights.1  stays_in_weekend_nights.2  \
# count              118901.000000              118901.000000
# mean                    1.928899                   2.928899
# std                     0.996212                   0.996212
# min                     1.000000                   2.000000
# 25%                     1.000000                   2.000000
# 50%                     2.000000                   3.000000
# 75%                     3.000000                   4.000000
# max                    17.000000                  18.000000
#
#        stays_in_weekend_nights.3         babies  is_repeated_guest  \
# count              118901.000000  118901.000000      118901.000000
# mean                    3.928899       0.007948           0.032010
# std                     0.996212       0.097379           0.176027
# min                     3.000000       0.000000           0.000000
# 25%                     3.000000       0.000000           0.000000
# 50%                     4.000000       0.000000           0.000000
# 75%                     5.000000       0.000000           0.000000
# max                    19.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           118901.000000                   118901.000000
# mean                 0.087140                        0.131631
# std                  0.845858                        1.484653
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes  days_in_waiting_list            adr  \
# count    118901.000000         118901.000000  118901.000000
# mean          0.221167              2.330695     101.956250
# std           0.652774             17.630234      48.092478
# min           0.000000              0.000000      -6.380000
# 25%           0.000000              0.000000      70.000000
# 50%           0.000000              0.000000      95.000000
# 75%           0.000000              0.000000     126.000000
# max          21.000000            391.000000     510.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                118901.000000              118901.000000
# mean                      0.061883                   0.571711
# std                       0.244169                   0.792680
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %% [markdown]
# # Data Analysis and Visualization

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize = (5,4))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'], df['is_canceled'].value_counts(), edgecolor='k', width = 0.7)
plt.show()
# Out:
# 0    0.628632
# 1    0.371368
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize = (8,4))
ax1=sns.countplot(x='hotel', hue='is_canceled', data=df,palette = 'Blues')
legend_labels= ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Registration status in different hotels', size=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
resort_hotel = df[df['hotel']== 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel']== 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582889
# 1    0.417111
# Name: is_canceled, dtype: float64

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize= 30)
plt.plot(resort_hotel.index, resort_hotel['adr'],label= 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'],label= 'City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='month',hue='is_canceled', data= df, palette='bright')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status per month', size=20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month', size=30)
sns.barplot(x='month', y= 'adr', data = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %%
cancelled_data=df[df['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country, autopct='%.2f', labels=top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474369
# Offline TA/TO    0.203186
# Groups           0.166576
# Direct           0.104701
# Corporate        0.042985
# Complementary    0.006173
# Aviation         0.001993
# Undefined        0.000017
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469676
# Groups           0.273961
# Offline TA/TO    0.187449
# Direct           0.043505
# Corporate        0.022149
# Complementary    0.002038
# Aviation         0.001178
# Undefined        0.000045
# Name: market_segment, dtype: float64

# %%
cancelled_df_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_data=df[df['is_canceled']==0]

not_cancelled_df_adr= not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate' , fontsize=30)
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend(fontsize=20)
plt.show()
